# %%
import requests
import pandas as pd
from io import StringIO

OBJID = '129362413827639236'
url = 'https://catalogs.mast.stsci.edu/api/v0.1/panstarrs/dr2/detection.csv'

r = requests.get(url,params={'objID':OBJID})
print(r.status_code)
if r.status_code == 200:
    df = pd.read_csv(StringIO(r.text))
df
# Out:
# 200
#                  objID    uniquePspsP2id            detectID         ippObjID  \
# 0   129362413827639236  3115001450000439  198052833450000438  145990233362470
# 1   129362413827639236  3115022450000432  198053894450000431  145990233362470
# 2   129362413827639236  3115045450000471  192762059450000470  145990233362470
# 3   129362413827639236  3115050130000382  225057604130000381  145990233362470
# 4   129362413827639236  3115061300000471  168629674300000470  145990233362470
# ..                 ...               ...                 ...              ...
# 88  129362413827639236  3121216710000291  264252498710000290  145990233362470
# 89  129362413827639236  3172969670000306  130631767670000305  145990233362470
# 90  129362413827639236  3172985670000299  130632961670000298  145990233362470
# 91  129362413827639236  3173001670000255  130433650670000254  145990233362470
# 92  129362413827639236  3173013670000230  130434792670000229  145990233362470
#
#     ippDetectID  filterID  surveyID   imageID  randomDetID  dvoRegionID  ...  \
# 0           438         3         0  49305345     0.746275        33991  ...
# 1           431         3         0  49307045     0.181321        33991  ...
# 2           470         4         0  47456645     0.321618        33991  ...
# 3           381         4         0  58431513     0.369854        33991  ...
# 4           470         3         0  37578230     0.415691        33991  ...
# ..          ...       ...       ...       ...          ...          ...  ...
# 88          290         1         0  72120571     0.971987        33991  ...
# 89          305         4         0  19955467     0.503709        33991  ...
# 90          298         4         0  19957467     0.270206        33991  ...
# 91          254         5         0  19830667     0.304540        33991  ...
# 92          229         5         0  19832967     0.636239        33991  ...
#
#     apRadius  kronFlux  kronFluxErr  kronRad       sky    skyErr   infoFlag  \
# 0    4.87419  0.000255     0.000009  4.07217  0.000157  0.000005  102776839
# 1    4.36116  0.000278     0.000010  4.05194  0.000171  0.000005  102776839
# 2    2.56570  0.000358     0.000010  3.50711  0.000087  0.000006  102776839
# 3    4.35944  0.000391     0.000010  4.33875  0.000065  0.000005  102776839
# 4    2.55394  0.000356     0.000006  4.24735  0.000058  0.000003  102776839
# ..       ...       ...          ...      ...       ...       ...        ...
# 88   3.31742  0.000127     0.000004  3.69083  0.000006  0.000002  102776839
# 89   2.80702  0.000374     0.000009  3.59176  0.000048  0.000005  102776839
# 90   2.55189  0.000362     0.000008  3.22278  0.000054  0.000005  102776839
# 91   2.04194  0.000340     0.000015  2.10072  0.000223  0.000014   35667969
# 92   2.29739  0.000360     0.000017  2.62634  0.000196  0.000013   35667969
#
#     infoFlag2  infoFlag3  processingVersion
# 0         128   91228224                  3
# 1         128    7342144                  3
# 2         128    7374912                  3
# 3         128   24152128                  3
# 4         128   74451008                  3
# ..        ...        ...                ...
# 88        128    7374912                  3
# 89        128    7374912                  3
# 90        128    7374912                  3
# 91        128   74451008                  3
# 92        128   74451008                  3
#
# [93 rows x 58 columns]
